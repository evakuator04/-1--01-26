# %% [markdown]
# <a href="https://colab.research.google.com/github/evakuator04/-1--01-26/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def f(x):
  return math.sqrt(1-x)-math.tan(x)
L=0
R=1
eps=0.0001
step=0
while abs(R-L)>eps:
  step+=1
  B=(L+R)/2
  print(step,'.',round(B,4))
  if f(L)*f(B)<=0:
    R=B
  else:
    L=B
answer=(L+R)/2
print(round(answer,4)) #для 13 варианта
# Out:
# 1 . 0.5
# 2 . 0.75
# 3 . 0.625
# 4 . 0.5625
# 5 . 0.5938
# 6 . 0.5781
# 7 . 0.5703
# 8 . 0.5742
# 9 . 0.5762
# 10 . 0.5771
# 11 . 0.5767
# 12 . 0.5769
# 13 . 0.5768
# 14 . 0.5767
# 0.5768

# %%
import math
def f(x):
  return math.sqrt(1-x)-math.tan(x)
a=0
b=1
eps=0.0001
step=0
x0=a
while True:
  step+=1
  x=a-(f(a)*(b-a))/(f(b)-f(a))
  print(step,round(x,4))
  if step>1 and abs(x-x0)<=eps:
    break
  x0=x
  if f(x)*f(b)>0:
    b=x
  else:
    a=x
print(round(x,4))
# Out:
# 1 0.391
# 2 0.5074
# 3 0.5496
# 4 0.5659
# 5 0.5724
# 6 0.575
# 7 0.5761
# 8 0.5765
# 9 0.5767
# 10 0.5767
# 0.5767
